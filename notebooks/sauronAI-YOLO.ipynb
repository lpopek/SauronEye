# %% [markdown]
# # Przygotowanie środowiska

# %% [markdown]
# http://localhost:8888/?token=ihrsyg1c3jv002lwki59

# %%
ssh-keygen -t ed25519 -C "lukasz.popek@rafalperz.pl"

# %% [markdown]
# 1. Sprawdzenie dostępnego sprzętu

# %%
# !nvidia-smi

# %% [markdown]
# 2. Pobranie zależności

# %%
# !pip install ultralytics

# %% [markdown]
# 3. Podłączenie dysku google

# %%
from google.colab import drive

drive.mount ('/content/drive')

# %% [markdown]
# # Trenowanie YOLO

# %% [markdown]
# Przed trenowaniem modelu należy sprawdzić czy konfiguracja datasetu się zgadza. W poniższym pliku `.yaml` wartość `path` powinna wskazywać na directory datasetu.

# %%
# !cat /content/drive/MyDrive/SauronEye/datasets/AI-TOD/yolo_dataset/data.yaml | grep path

# %%
# !yolo train model=yolo11m.pt data=/content/drive/MyDrive/SauronEye/datasets/AI-TOD/yolo_dataset/data.yaml epochs=20 imgsz=800 batch=4
